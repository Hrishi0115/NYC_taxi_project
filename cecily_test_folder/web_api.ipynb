# %%
import requests

# %%
url = r'https://www.opendatanetwork.com/search?q=green+taxi+trip+data'
r = requests.get(url)

# %%
response = r.text

# %%
response
# Out:
# '<!doctype html><html lang=en><head><meta charset=utf-8><meta name=viewport content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no"><meta name=keywords content="open data, government data, housing data, restaurant inspecitions data, transit data, health data, crime data, permit data"><title>Data on the Open Data Network</title><link href=/styles/search.css rel=stylesheet><link href=/styles/main.css rel=stylesheet><script defer src=/lib/third-party/browser-polyfill.min.js></script><script defer src=//ajax.googleapis.com/ajax/libs/jquery/2.1.3/jquery.min.js></script><script defer src=/lib/third-party/d3.min.js></script><script defer src=/lib/third-party/d3.promise.min.js></script><script defer src=/lib/third-party/lodash.min.js></script><script defer src=/lib/third-party/colorbrewer.min.js></script><script defer src=/lib/search.min.js></script></head><body><header role=banner><h1 class=logo><a href=/ title="Open Data Network"><span class=sr-only>Open Data Network<
# ...

# %%
# search for year
r_2016 = response[response.find(">2016")-10:response.find(">2016")]
r_2016
# Out:
# '/hvrh-b6nb'

# %%
green_taxi_endpoints = []
