# %%
import pyarrow.parquet as pq
 
f_yellow = r"C:\Users\HrishiSingh\Downloads\yellow_tripdata_2024-01.parquet"
yellow = pq.read_table(f_yellow)
yellow = yellow.to_pandas()
display(yellow)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...           ...                  ...                   ...              ...
# 2964619         2  2024-01-31 23:45:59   2024-01-31 23:54:36              NaN
# 2964620         1  2024-01-31 23:13:07   2024-01-31 23:27:52              NaN
# 2964621         2  2024-01-31 23:19:00   2024-01-31 23:38:00              NaN
# 2964622         2  2024-01-31 23:07:23   2024-01-31 23:25:14              NaN
# 2964623         1  2024-01-31 23:58:25   2024-02-01 00:13:30              NaN
#
# ...

# %%
f_green = r"C:\Users\HrishiSingh\Downloads\green_tripdata_2019-02.parquet" 
green = pq.read_table(f_green)
green = green.to_pandas()
display(green)
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              2  2019-02-01 00:10:19   2019-02-01 00:21:43
# 1              2  2019-02-01 00:02:16   2019-02-01 00:24:37
# 2              2  2019-02-01 00:37:19   2019-02-01 00:43:07
# 3              1  2019-02-01 00:10:10   2019-02-01 00:12:21
# 4              1  2019-02-01 00:30:19   2019-02-01 00:46:14
# ...          ...                  ...                   ...
# 615589         2  2019-02-28 23:11:00   2019-02-28 23:30:00
# 615590         2  2019-02-28 23:11:00   2019-02-28 23:47:00
# 615591         2  2019-02-28 23:27:00   2019-03-01 00:07:00
# 615592         2  2019-02-28 23:14:00   2019-02-28 23:43:00
# 615593         2  2019-02-28 23:32:00   2019-03-01 00:08:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0            92           135
# 1                       N         1.0            66            36
# ...

# %%
f_fhv = r"C:\Users\HrishiSingh\Downloads\fhv_tripdata_2019-02.parquet"
fhv = pq.read_table(f_fhv)
fhv = fhv.to_pandas()
display(fhv)
# Out:
#         dispatching_base_num     pickup_datetime    dropOff_datetime  \
# 0                     B00037 2019-02-01 00:08:44 2019-02-01 00:23:35
# 1                     B00037 2019-02-01 00:27:51 2019-02-01 00:32:54
# 2                     B00037 2019-02-01 00:18:30 2019-02-01 00:25:45
# 3                     B00037 2019-02-01 00:43:15 2019-02-01 00:48:29
# 4                     B00037 2019-02-01 00:01:45 2019-02-01 00:09:13
# ...                      ...                 ...                 ...
# 1707645               B03129 2019-02-28 23:55:25 2019-03-01 00:06:18
# 1707646               B03157 2019-02-28 23:35:26 2019-02-28 23:39:00
# 1707647               B03157 2019-02-28 23:13:40 2019-02-28 23:17:24
# 1707648               B03157 2019-02-28 23:18:45 2019-02-28 23:56:57
# 1707649               B03177 2019-02-28 23:45:40 2019-02-28 23:49:41
#
#          PUlocationID  DOlocationID  SR_Flag Affiliated_base_number
# 0               264.0         265.0      NaN                 B00037
# ...

# %%
f_fhvhv= r"C:\Users\HrishiSingh\Downloads\fhvhv_tripdata_2019-02.parquet"
fhvhv = pq.read_table(f_fhvhv)
fhvhv = fhvhv.to_pandas()
display(fhvhv)
# Out:
#          hvfhs_license_num dispatching_base_num originating_base_num  \
# 0                   HV0003               B02867               B02867
# 1                   HV0003               B02879               B02879
# 2                   HV0005               B02510                 None
# 3                   HV0005               B02510                 None
# 4                   HV0005               B02510                 None
# ...                    ...                  ...                  ...
# 20159097            HV0005               B02510                 None
# 20159098            HV0003               B02395               B02395
# 20159099            HV0003               B02395               B02395
# 20159100            HV0003               B02395               B02395
# 20159101            HV0003               B02395               B02395
#
#             request_datetime   on_scene_datetime     pickup_datetime  \
# ...

# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\HrishiSingh\Downloads\taxi_zone_lookup.csv")
df
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                      NaN          NaN
# 264         265            NaN           Outside of NYC          NaN
#
# [265 rows x 4 columns]
