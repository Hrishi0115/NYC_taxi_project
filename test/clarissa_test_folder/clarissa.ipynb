# %%
import pyarrow.parquet as pq

filename = r"C:\Users\ClarissaOmolu\Downloads\yellow_tripdata_2019-09.parquet"
trips = pq.read_table(filename)
trips = trips.to_pandas()

# %%
display(trips)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2019-09-01 00:06:48   2019-09-01 00:25:46              1.0
# 1               1  2019-09-01 00:29:17   2019-09-01 00:57:54              1.0
# 2               1  2019-09-01 00:41:32   2019-09-01 00:41:36              1.0
# 3               1  2019-09-01 00:59:11   2019-09-01 00:59:15              1.0
# 4               1  2019-09-01 00:39:41   2019-09-01 00:45:06              1.0
# ...           ...                  ...                   ...              ...
# 6567783         2  2019-09-30 23:32:00   2019-09-30 23:58:00              NaN
# 6567784         2  2019-09-30 23:51:00   2019-10-01 00:11:00              NaN
# 6567785         2  2019-09-30 23:43:00   2019-10-01 00:06:00              NaN
# 6567786         2  2019-09-30 23:51:34   2019-10-01 00:32:04              NaN
# 6567787         2  2019-09-30 23:17:00   2019-09-30 23:35:00              NaN
#
# ...
